# %%
from ultralytics import YOLO
import torch

# %%
model = YOLO("yolov8n.pt")

# %%
torch.cuda.is_available()
# Out:
# True

# %%
model.train(data='data/yamls/deepfashion2.yaml', epochs=10, batch=16, device='0')
# Out:
# Ultralytics YOLOv8.1.44  Python-3.11.4 torch-2.2.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11264MiB)
# ...
